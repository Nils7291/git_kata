# %%
# %reload_ext autoreload
# %autoreload 2

from utils import load_data, clean_data

titanic = load_data()

titanic.head()

clean = clean_data(titanic)
clean.head()

import matplotlib.pyplot as plt
import seaborn as sns

# Count the occurrences of each passenger class
pclass_counts = clean['pclass'].value_counts().sort_index()

# Create a bar plot using Matplotlib
plt.figure(figsize=(8, 6))
plt.bar(pclass_counts.index, pclass_counts.values)
plt.xlabel("Passenger Class")
plt.ylabel("Number of Passengers")
plt.title("Distribution of Passenger Classes")
plt.xticks(pclass_counts.index) # Ensure x-axis labels are correct
plt.grid(axis='y', linestyle='--')
plt.show()

# Alternatively, using Seaborn for a potentially more visually appealing plot
plt.figure(figsize=(8, 6))
sns.countplot(data=clean, x='pclass', order=clean['pclass'].value_counts().index)
plt.xlabel("Passenger Class")
plt.ylabel("Number of Passengers")
plt.title("Distribution of Passenger Classes")
plt.show()
